# %%
from gensim.models import Word2Vec
import numpy as np
from sklearn.decomposition import PCA
#import matplotlib.pyplot as plt
import matplotlib.pyplot as pyplot
from __future__ import print_function
import collections
import math
import numpy as np
import pandas as pd
import os
import csv
from csv import reader
import random
import tensorflow as tf
from gensim.models import word2vec
# %matplotlib inline

# %%
df=pd.read_excel('/home/sungwoo/Ethnography.xlsx');

# %%
df3 = df.reindex(columns=['Time','Location', 'Thing' ]).dropna(how='any').sort_values('Thing');
from gensim.models import word2vec
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
with open('sentences.txt' , 'w') as fp:
    for value in df3.values:
        print(value)
        Location = value[1].replace(' ', '')
        for Thing in value[2].split(','):
            fp.write('%s %s  \n' % (Location,Thing.replace(' ', '')))
# Out:
# [datetime.time(16, 57) 'time square' '3D scanner']
# ['5/3' 'cafe' 'A cup']
# [datetime.time(20, 5) 'Incheon University' 'ATM']
# [datetime.datetime(2017, 4, 30, 15, 0) 'café' 'Air-conditioner']
# ['5/1' 'Inha University' 'Airplane']
# ['am 00:25' 'home' 'All-in-one (printer,fax,etc)']
# ['Pm 4:17' 'GYM' 'Babel']
# [datetime.datetime(2017, 5, 4, 15, 0) 'basketball court' 'Basketball']
# ['4/30' 'Busan' 'Beach(sand)']
# ['4/30' 'Busan' 'Beach(sand)']
# ['Pm 4:12' 'Home' 'Bed']
# ['5/4' 'Central Park' 'Bicycle']
# [datetime.time(15, 19) 'song-nae station' 'Bicycle']
# ['Pm 3:42' 'Street' 'Bicycle']
# [datetime.time(16, 0) 'Billiard room' 'Billiard']
# [datetime.time(23, 0) 'Billiard room' 'Billiard']
# [datetime.time(18, 24) 'Billiard room' 'Billiard']
# [datetime.time(23, 20) 'Billiard room' 'Billiard']
# ['pm 21:32' 'street' 'Block']
# ['Pm 4:21' 'Lecture room' 'Board']
# ['4/28' 'Dormitory' 'Book']
# [datetime.time(20, 21) 'Home' 'Book']
# ['Pm 4:58' 'Bus' 'Book']
# ['Pm 8:49' 'Lecture room' 'Book']
# ['5/2' 'Study public organizations' 'Book']
# ['5/2' 'Dormitory' 'Book']
# ['Am 10:37' 'Home' 'Bookshelf']
# ['4/30' 'Busan seashore' 'Bridge']
# ['pm 14:37' 'temple' 'Buddhism light']
# ['Pm 12:46' 'Restaurant' 'Burner']
# ['4/29' 'On the way to Busan' 'Bus']
# ['4/29' 'On the way to Busan' 'Bus']
# ['Pm 3:55' 'Bus' 'Bus card']
# ['Pm 7:30' 'Street' 'Bus stop']
# ['Am 11:13' 'Home' 'Calendar']
# [datetime.datetime(2017, 4, 29, 14, 0) 'Road' 'Car']
# ['4/29' 'Busan' 'Cars']
# ['4/29' 'Listen to music' 'Cell phone']
# ['4/29' 'Book the ticket to Busan(Bus terminal)' 'Cell phone']
# ['Pm 8:23' 'PC room' 'Chair']
# ['Pm 8:08' 'Home' 'Charger']
# ['pm 19:04' 'restaurent' 'Check-stand machine']
# ['4/28' 'Dormitory' 'Chess']
# ['Pm 2:13' 'Restaurant' 'Chopsticks']
# [datetime.time(19, 0) 'sang-dong' 'Claw machine']
# [datetime.datetime(2017, 5, 3, 19, 0) 'Domitory Room' 'Cleaning machine']
# [datetime.datetime(2017, 4, 29, 11, 0) 'House' 'Cleaning machine']
# [datetime.datetime(2017, 5, 1, 10, 0) 'Home' 'Cleaning machine']
# ['5/4' 'Triple street' 'Clothes']
# ['5/1' 'Traditional Village' 'Clothes']
# [datetime.datetime(2017, 4, 29, 14, 0) 'Starbucks' 'Coffee']
# [datetime.time(12, 8) 'songdo' 'Computer']
# ['Am 12:26' 'Home' 'Computer']
# [datetime.time(22, 23) 'Dongchun' 'Computer']
# ['Pm 4:11' 'Home' 'Cup']
# ['pm 16:00' 'laboratory' 'DC power supply']
# [datetime.datetime(2017, 5, 2, 17, 0) 'Cafeteria' 'Dinner']
# [datetime.datetime(2017, 4, 28, 19, 0) 'Domitory Room' 'Dinner']
# [datetime.time(18, 30) 'Meat buffet' 'Dinner']
# [datetime.time(16, 47) 'seoul' 'Dinner']
# ['4/29' 'Busan' 'Dinner']
# [datetime.datetime(2017, 4, 29, 19, 0) 'Restaurant' 'Dinner']
# ['5/2' 'Eating food' 'Dishes']
# ['5/3' 'Dinner' 'Dishes(eating food)']
# [datetime.datetime(2017, 4, 30, 10, 0) 'Home' 'Doing Laundry']
# [datetime.time(14, 55) 'doll drawing shop' 'Doll']
# ['Pm 2:06' 'Home' 'Drawer']
# ['Pm 2:01' 'Street' 'Earphone']
# ['pm 13:12' 'home' 'Electric Heat plate']
# [datetime.datetime(2017, 5, 2, 12, 0) 'Home' 'Electric inductor to cook']
# [datetime.datetime(2017, 4, 28, 21, 0) 'Gym' 'Exercising']
# [datetime.datetime(2017, 4, 29, 19, 0) 'House' 'Exercising crossfit']
# ['Pm 6:56' 'School' 'Experimental machine']
# [datetime.time(13, 3) 'student restarant' 'Food']
# [datetime.time(16, 10) 'Bucheon ' 'Fork to eat']
# ['5/1' 'China town' 'Gate']
# [datetime.time(8, 40) 'subway station' 'Go to school']
# ['7:29pm' 'wharf' 'Grilled shellfish']
# [datetime.time(12, 0) 'Hair salon' 'Hair cut']
# ['Am 10:39' 'Home' 'Hair dryer']
# [datetime.time(20, 22) 'ilsan' 'Haircut']
# [datetime.time(20, 21) "Mcdonald's" 'Hamburger']
# [datetime.time(19, 0) 'going to home' 'Hamburger']
# [datetime.time(12, 11) 'restaurent' 'Hamburger']
# [datetime.time(20, 11) 'Dongchun' 'Hamburger']
# [datetime.time(20, 0) 'inu popeyes' 'Hamburger']
# [datetime.time(14, 35) 'Guwol-dong' 'Hamburger']
# [datetime.time(13, 0) '518 lecture room' 'Hamburger']
# ['7:02pm' 'Jeon-ju' 'Hanbok']
# ['pm 15:24' 'home' 'Hand size Cleaner']
# ['5/3' 'Sea' 'Handrail']
# ['Pm 4:06' 'Home' 'Headset']
# ['5/3' 'On the road' 'Icecream']
# [datetime.time(18, 30) 'Incheon international airport' 'Information system']
# ['Am 9:42' 'Baths' 'Key']
# ['Pm 10:24' 'Lecture room' 'Keyboard']
# ['Pm 2:57' 'Home' 'Light']
# ['Pm 7:21' 'School' 'Lighter']
# [datetime.time(23, 0) 'oido station' 'MT on the way']
# ['4/30' 'Busan' 'Motorcycle']
# ['Pm 3:40' 'Home' 'Mouse']
# [datetime.datetime(2017, 5, 2, 12, 0) 'Domitory Room' 'NBA Series']
# [datetime.datetime(2017, 4, 28, 21, 0) 'PC room' 'PC&LOL']
# [datetime.datetime(2017, 5, 2, 14, 13) 'physical laboratory'
#  'PC, laboratory equipment']
# [datetime.time(22, 0) 'home' 'PPT']
# ['4/28' 'Dormitory' 'Pen']
# [datetime.time(15, 42) 'phone case store' 'Phone case']
# ['4/30' 'In the museum' 'Picture']
# ['Pm 12:47' 'Home' 'Pillow']
# ['4/30' 'Busan' 'Pork']
# ['5/3' 'INU' 'Presentation(have a class)']
# [datetime.time(11, 48) 'Incheon international airport' 'QLED TV']
# [datetime.datetime(2017, 5, 4, 20, 0) 'Street' 'ROAD SIGNAL']
# [datetime.time(13, 0) 'home' 'Rabokki']
# ['Pm 12:11' 'Restaurant' 'Radios']
# [datetime.time(13, 0) 'home' 'Ramen']
# [datetime.datetime(2017, 4, 30, 19, 0) 'Domitory Room' 'Ramyon']
# ['5/2' 'Dormitory' 'Raspberry pi']
# ['Pm 7:28' 'Home' 'Remote control']
# [datetime.datetime(2017, 5, 1, 10, 0) 'INU' 'Road']
# [datetime.datetime(2017, 5, 4, 10, 0) 'Road' 'Road block']
# ['Pm 12:35' 'Home' 'Scale']
# [datetime.datetime(2017, 5, 4, 10, 0) 'Classroom' 'Screen']
# ['Pm 8:57' 'Home' 'Secondary battery']
# ['Pm 8:42' 'Home' 'Shaver']
# [datetime.datetime(2017, 4, 30, 10, 0) 'Ncstore' 'Shopping']
# ['5/3' 'Homeplus' 'Shopping cart']
# ['Pm 12:08' 'Restroom' 'Shower head']
# [datetime.datetime(2017, 5, 2, 19, 0) 'Convenience Store' 'SomeThing']
# ['Pm 8:34' 'Home' 'Speaker']
# ['Am 11:24' 'Restaurant' 'Spoon']
# ['Pm 11:35' 'Park' 'Street lamp']
# ['5/1' 'Subway Station' 'Subway']
# ['5/1' 'Busan Station' 'Subway station']
# [datetime.datetime(2017, 4, 28, 9, 0) 'Domitory Room' 'Sushi']
# ['Pm 2:05' 'Home' 'Switch']
# [datetime.time(21, 0) 'home' 'TV']
# [datetime.time(18, 30) 'home' 'TV']
# [datetime.datetime(2017, 4, 29, 23, 45) 'home' 'TV']
# [datetime.datetime(2017, 5, 5, 14, 27) 'House' 'TV']
# [datetime.time(18, 59) 'home' 'TV']
# [datetime.datetime(2017, 4, 29, 20, 32) 'home' 'TV']
# [datetime.time(12, 0) 'home' 'TV']
# [datetime.datetime(2017, 4, 30, 23, 5) 'House' 'TV']
# [datetime.time(12, 0) 'home' 'TV']
# [datetime.time(23, 29) 'Guwol-dong' 'TV']
# [datetime.time(14, 35) 'home' 'TV']
# [datetime.datetime(2017, 5, 2, 22, 20) 'home' 'TV']
# ['pm 12:01' 'home' 'TV']
# [datetime.time(11, 34) 'Guwol-dong' 'TV']
# [datetime.datetime(2017, 5, 4, 8, 56) 'home' 'TV']
# [datetime.time(16, 0) 'home' 'TV controller']
# [datetime.datetime(2017, 4, 28, 9, 0) 'Home' 'TV&wifi']
# [datetime.time(12, 13) 'cafe' 'TV,DVD']
# ['Am 12:39' 'Restaurant' 'Table']
# ['5/4' 'Megabox' 'Table&chairs']
# ['Pm 8:39' 'Home' 'Thermostat']
# [datetime.datetime(2017, 5, 1, 13, 0) 'Cafeterua' 'Ticket Machine']
# ['Am 11:06' 'Restroom' 'Toilet']
# ['5/1' 'Bus' 'Transfer account']
# [datetime.time(15, 42) 'park' 'Tulip']
# ['Pm 5:00' 'Street' 'Wallet']
# [datetime.datetime(2017, 5, 3, 12, 0) 'subway' 'Webtoon']
# [datetime.datetime(2017, 5, 5, 12, 8) 'House' 'air conditioner']
# [datetime.datetime(2017, 5, 5, 12, 5) 'House' 'air conditioner']
# ['pm 12:40' 'home' 'air controller']
# [datetime.time(22, 10) 'Gapyeong' 'alcohol game']
# [datetime.time(11, 0) 'Inu' 'assignment']
# [datetime.time(19, 0) 'home' 'assignment']
# ['2:21pm' 'cafe' 'assignment']
# [datetime.datetime(2017, 4, 30, 19, 0) 'Bank in Mart' 'atm machine']
# ['pm 20:45' 'near home' 'bacchus']
# ['Pm 7:22' 'Street' 'backpack']
# [datetime.time(19, 0) 'subway' 'bag']
# ['pm 14:00' 'cafe' 'ballpen']
# [datetime.time(19, 10) 'baseball stadium' 'baseball game']
# [datetime.time(14, 20) 'baseball stadium' 'baseball game']
# [datetime.datetime(2017, 5, 4, 20, 0) 'baseball game palce' 'batting ball']
# ['pm 12:38' 'class room' 'beam projector']
# [datetime.datetime(2017, 5, 1, 18, 52) 'inu' 'beam projector']
# [datetime.time(17, 25) 'house' 'bed']
# [datetime.time(12, 0) 'home' 'bed']
# [datetime.time(12, 0) 'home' 'bed']
# [datetime.time(21, 0) 'bar' 'beer']
# ['pm 19:27' 'restaurent' 'beer container']
# [datetime.time(20, 5) 'sondo pub' 'beer machine']
# [datetime.time(12, 30) 'home' 'beverage']
# [datetime.time(17, 30) 'home' 'beverage']
# [datetime.time(11, 48) 'convenience store' 'beverage']
# [datetime.time(22, 30) 'park' 'bicycle']
# [datetime.time(12, 0) 'home' 'big grape']
# [datetime.time(11, 46) 'university' 'blanket']
# [datetime.time(11, 3) 'home' 'board game']
# [datetime.time(12, 38) 'university' 'book']
# [datetime.time(14, 1) 'chinese academy' 'book']
# [datetime.time(22, 42) 'Guwol-dong' 'book']
# [datetime.time(12, 13) '518 lecture room' 'book']
# [datetime.time(16, 49) 'home' 'book']
# [datetime.time(13, 50) '216 lecture room' 'book']
# [datetime.time(13, 0) 'lecture room' 'book']
# [datetime.time(18, 58) 'home' 'book']
# [datetime.time(20, 59) 'home' 'book']
# [datetime.time(8, 29) 'Dongchun' 'book']
# [datetime.datetime(2017, 5, 1, 12, 59) 'library' 'book']
# [datetime.time(18, 48) 'home' 'book']
# [datetime.time(21, 14) 'home' 'book']
# [datetime.datetime(2017, 5, 1, 18, 50) 'library' 'book']
# [datetime.time(18, 4) 'university' 'book']
# [datetime.time(19, 53) '515 lecture room' 'book']
# [datetime.time(11, 46) 'university' 'book']
# [datetime.time(18, 58) 'home' 'book']
# [datetime.time(17, 19) 'university' 'book']
# ['am 24:21' 'home' 'book  ']
# ['pm 15:49' 'class room' 'book & beam projector']
# [datetime.time(14, 58) '443 lecture room' 'book, pencil']
# [datetime.time(21, 0) 'bowling alley' 'bowling ball']
# [datetime.time(9, 27) 'street' 'building']
# [datetime.time(17, 30) 'rooftop' 'building']
# [datetime.time(20, 0) 'home' 'burden']
# [datetime.time(13, 2) 'Ansan' 'bus']
# ['12:48pm' 'bus stop' 'bus']
# [datetime.time(19, 28) 'Ansan' 'bus']
# ['pm 12:22' 'bus' 'bus']
# [datetime.time(10, 0) 'home' 'bus']
# ['2:45pm' 'Dae-gu bus station' 'bus']
# [datetime.time(17, 30) 'jung-dong' 'bus']
# ['1:16pm' 'Incheon terminal' 'bus']
# ['8:39pm' 'Bus station' 'bus  ']
# [datetime.time(22, 14) 'bus stop' 'bus  ']
# ['pm 22:17' 'subway' 'bus card']
# [datetime.time(17, 25) 'Ga-jung station' 'bus information machine']
# [datetime.datetime(2017, 5, 3, 19, 0) 'Bus station'
#  'bus information machine']
# ['pm 18:29' 'subway station' 'bus stop']
# [datetime.time(14, 33) 'bus' 'bus stop']
# [datetime.time(11, 34) 'Daehwa-dong' 'bus stop']
# [datetime.time(12, 35) 'Bucheon ' 'bus stop']
# [datetime.time(12, 19) 'bus stop' 'bus system']
# [datetime.time(9, 55) 'Baeksuk-dong' 'café']
# [datetime.time(20, 33) 'bakery' 'cake']
# [datetime.time(18, 40) 'Eul-wang-ri' 'camera']
# [datetime.time(17, 5) 'triple street' 'camera']
# ['pm 14:00' 'cafe' 'camera']
# [datetime.time(19, 44) 'expressway' 'car']
# [datetime.time(17, 59) 'Guro' 'car']
# [datetime.time(11, 18) 'road' 'car']
# [datetime.datetime(2017, 5, 3, 23, 27) 'parking lot' 'car']
# [datetime.time(8, 29) 'Bupyeong' 'car']
# [datetime.time(20, 40) 'road' 'car']
# [datetime.time(11, 20) 'Gang-hwa' 'car']
# ['pm 12:30' 'street' 'car window']
# ['pm 21:05' 'bus terminal' "car's back window"]
# ['pm 19:00' 'bus' 'card reader']
# ['pm 13:00' 'convenience store' 'card reader']
# [datetime.time(22, 0) 'home' 'carrier']
# [datetime.time(20, 0) 'subway station' 'carrier']
# ['5:06pm' 'cartoon cafe' 'cartoon']
# [datetime.time(20, 0) 'cartoon café' 'cartoon']
# [datetime.time(12, 30) 'cartoon cafe' 'cartoon']
# [datetime.time(21, 28) 'home' 'cat']
# ['pm 13:00' 'cafe' 'chair']
# [datetime.time(15, 50) 'bus' 'chair']
# [datetime.time(22, 0) 'Guwol-dong' 'chair']
# [datetime.time(14, 0) 'home' 'charging a cellphone']
# [datetime.time(17, 45) 'home' 'charging a cellphone']
# [datetime.time(22, 0) 'baseball stadium' 'cheer leader']
# ['pm 23:10' 'home' 'chicken']
# [datetime.time(18, 30) 'BBQ' 'chicken']
# [datetime.time(19, 0) 'river' 'chicken']
# ['5:03pm' 'chiken store' 'chicken']
# [datetime.time(18, 0) 'sondo  ' 'churros']
# [datetime.time(20, 11) 'school' 'cigarette']
# [datetime.datetime(2017, 5, 1, 20, 0) 'Domitory Room' 'cleansing foams']
# ['pm 15:20' 'home' 'clock']
# ['pm 15:02' 'home' 'clock']
# [datetime.time(21, 20) 'home' 'closet']
# [datetime.time(18, 30) 'home' 'closet']
# [datetime.time(21, 56) 'Homeplus' 'cloth']
# ['pm 14:33' 'street' 'cloth']
# [datetime.time(11, 0) 'home' 'cloth']
# [datetime.time(14, 20) 'cloth store' 'cloth']
# ['pm 18:35' 'shopping mall' 'cloth']
# ['pm 18:16' 'street' 'cobbled road']
# [datetime.time(17, 45) 'cafe' 'coffee']
# [datetime.time(10, 25) 'cafe' 'coffee']
# ['2:19pm' 'cafe' 'coffee']
# ['pm 14:00' 'restaurent' 'coffee dispencer']
# [datetime.time(18, 58) 'cafe' 'coffee machine']
# [datetime.datetime(2017, 5, 2, 11, 14) 'chinese food restaurant'
#  'coffee machine']
# ['5:16pm' 'Restaurant' 'cold noodles']
# [datetime.time(10, 32) 'cafe' 'comic book, coffee']
# [datetime.time(17, 27) 'house' 'computer']
# [datetime.time(18, 58) 'PC room' 'computer']
# [datetime.time(20, 48) 'house' 'computer']
# [datetime.time(14, 37) '326 lecture room' 'computer']
# [datetime.time(20, 10) 'house' 'computer']
# [datetime.time(20, 21) 'home' 'computer']
# [datetime.time(16, 47) 'house' 'computer']
# [datetime.time(22, 51) 'home' 'computer']
# [datetime.time(19, 50) 'home' 'computer']
# [datetime.datetime(2017, 5, 4, 15, 0) 'Classroom' 'computer']
# [datetime.time(19, 30) 'house' 'computer']
# [datetime.time(22, 14) 'house' 'computer']
# [datetime.time(13, 43) 'house' 'computer']
# [datetime.time(13, 41) 'house' 'computer']
# ['8:35pm' 'Inha University' 'computer']
# [datetime.time(20, 48) '326 lecture room' 'computer']
# [datetime.time(20, 26) 'house' 'computer']
# [datetime.time(16, 38) 'class room' 'computer']
# ['pm 21:40' 'home' 'computer']
# ['pm 19:04' 'home' 'computer']
# [datetime.time(22, 0) 'pc room' 'computer']
# ['pm 14:51' 'pc room' 'computer']
# [datetime.time(22, 0) 'home' 'computer']
# ['pm 15:10' 'class room' 'computer']
# [datetime.time(19, 0) 'home' 'computer']
# ['pm 21:50' 'street' 'computer']
# [datetime.time(23, 0) 'home' 'computer']
# ['pm 20:40' 'home' 'computer']
# ['pm 11:52' 'home' 'computer']
# [datetime.time(19, 22) 'Baeksuk-dong' 'computer']
# [datetime.time(23, 0) 'home' 'computer']
# ['pm 21:58' 'home' 'computer']
# ['pm 23:15' 'pc room' 'computer']
# ['pm 21:02' 'home' 'computer']
# [datetime.time(14, 52) 'zoo' 'cranes']
# ['pm 21:26' 'street' 'crosswalk']
# ['pm 18:00' 'cafe' 'cube toy']
# [datetime.time(18, 0) 'Billiard room' 'cue stick']
# [datetime.time(18, 0) 'Billiard room' 'cue stick']
# [datetime.time(19, 0) 'Billiard room' 'cue stick']
# ['am 11:00' 'cafe' 'cup']
# [datetime.time(17, 19) 'internet cafe' 'desktop']
# [datetime.time(11, 6) 'classroom' 'desktop']
# [datetime.time(21, 0) 'home' 'desktop']
# [datetime.time(11, 5) 'classroom' 'desktop']
# [datetime.time(11, 5) 'classroom' 'desktop']
# [datetime.time(18, 8) 'cafe' 'dessert']
# [datetime.time(21, 23) 'Bucheon' 'dinner']
# [datetime.time(19, 51) 'house' 'dinner']
# ['pm 15:50' 'subway' 'display board']
# [datetime.time(22, 50) 'subway station' 'display board']
# [datetime.time(18, 10) 'Si-heung' 'dog']
# ['pm 15:05' "girl's rest room" 'door and table']
# ['pm 13:00' 'home' 'door locker']
# [datetime.time(11, 4) 'Campus' 'drink ']
# [datetime.time(20, 11) 'home' 'drinking']
# [datetime.time(21, 24) 'bar' 'drinking']
# ['pm 13:00' 'cafe' 'drug bottle']
# [datetime.time(16, 10) 'home' 'drying rack']
# ['am 11:00' 'cafe' 'earphones']
# ['pm 18:11' 'home' 'electric kettle']
# [datetime.datetime(2017, 4, 30, 11, 22) 'seoul grand park' 'elephant train']
# [datetime.datetime(2017, 5, 3, 17, 0) 'building' 'elevator']
# [datetime.time(12, 50) 'Incheon University' 'elevator']
# [datetime.time(9, 25) 'Incheon University' 'english book']
# [datetime.time(23, 0) 'home' 'errand']
# [datetime.datetime(2017, 5, 3, 11, 5) 'costco' 'escalator']
# [datetime.datetime(2017, 5, 2, 19, 0) 'Mart' 'escalator']
# [datetime.time(17, 26) 'woninjae' 'escalator']
# [datetime.datetime(2017, 5, 1, 9, 24) 'subway' 'escalator']
# [datetime.datetime(2017, 4, 28, 19, 0) 'University lab'
#  'experiment equipment']
# [datetime.time(21, 3) 'home' 'feeding dog']
# [datetime.time(21, 9) 'clothing store' 'fitting room']
# [datetime.time(18, 0) 'home' 'flower  ']
# ['3:49pm' 'inu' 'flower pot']
# ['pm 13:00' 'cafe' 'flower pot']
# [datetime.time(13, 50) 'house' 'flower pot']
# [datetime.time(17, 45) 'street' 'flower pot']
# ['4:47pm' 'library' 'flower pot']
# ['10:05pm' 'Restaurant' 'food']
# [datetime.time(21, 11) 'house' 'food']
# [datetime.time(17, 22) 'shangchai' 'food']
# [datetime.time(17, 51) 'house' 'food']
# [datetime.time(20, 26) 'Bupyeong' 'food']
# ['10:32pm' 'Bucheon' 'food']
# [datetime.time(17, 3) 'park' 'food']
# [datetime.time(14, 0) 'electronic room' 'friends']
# [datetime.time(21, 4) 'park' 'friends']
# [datetime.time(20, 30) 'Incheon terminal' 'game']
# ['pm 19:00' 'restaurent' 'gas burner']
# [datetime.time(12, 0) 'rest room' 'gimbab']
# [datetime.time(20, 22) 'subway station' 'go home']
# [datetime.time(17, 0) 'university' 'guide map']
# [datetime.time(13, 0) 'home' 'hair dryer']
# [datetime.time(15, 0) 'oliveyoung' 'hair essense']
# [datetime.time(15, 0) 'subway' 'hand cream']
# [datetime.time(18, 40) 'house' 'hand-wash']
# ['pm 12:30' 'street' 'handrail & cigarette']
# [datetime.time(16, 39) 'library' 'homework']
# [datetime.time(18, 0) 'theater' 'hotdog']
# [datetime.time(12, 8) 'subway station' 'iPhone']
# [datetime.datetime(2017, 5, 4, 12, 35) 'restaurant' 'induction']
# [datetime.time(12, 11) 'restaurent' 'japanese cuisine']
# ['pm 23:55' 'karaoke  ' 'karaoke machine']
# [datetime.time(19, 23) 'home' 'keyboard']
# ['pm 19:00' 'home' 'knife']
# [datetime.time(19, 0) 'bar' 'lamb stick with father']
# ['pm 15:20' 'café' 'laptop']
# [datetime.time(19, 10) 'home' 'laptop']
# [datetime.time(20, 11) 'home' 'laptop']
# [datetime.time(14, 53) 'classroom' 'laptop']
# [datetime.time(10, 0) 'home' 'laptop']
# [datetime.time(13, 0) 'home' 'laptop']
# [datetime.time(16, 47) 'songdo' 'laptop']
# [datetime.time(14, 53) 'classroom' 'laptop']
# [datetime.datetime(2017, 5, 4, 16, 55) 'inu' 'laptop']
# [datetime.time(22, 20) 'home' 'laptop']
# [datetime.time(22, 0) 'home' 'laptop']
# [datetime.time(13, 51) 'Dongchun' 'laptop']
# [datetime.time(16, 51) 'cafe' 'laptop']
# [datetime.time(13, 51) 'Guwol-dong' 'laptop']
# [datetime.time(16, 36) 'Guwol-dong' 'laptop']
# [datetime.time(12, 38) 'university' 'laptop']
# ['pm 12:34' 'home' 'laptop']
# [datetime.datetime(2017, 5, 3, 10, 54) 'home' 'laptop']
# [datetime.datetime(2017, 4, 30, 10, 54) 'home' 'laptop']
# ['pm 18:15' 'home' 'laptop']
# [datetime.time(11, 26) 'home' 'laptop']
# [datetime.datetime(2017, 4, 29, 16, 43) 'Lisan Costco' 'laptop']
# [datetime.time(22, 42) 'Dongchun' 'laptop']
# [datetime.datetime(2017, 4, 29, 16, 17) 'home' 'laptop']
# [datetime.datetime(2017, 5, 4, 12, 32) 'library' 'laptop']
# [datetime.time(18, 47) 'home' 'laptop']
# [datetime.time(16, 57) 'Guwol-dong' 'laptop']
# [datetime.datetime(2017, 5, 2, 10, 52) 'library' 'laptop']
# [datetime.time(16, 36) 'Dongchun' 'laptop']
# [datetime.time(16, 0) 'inu' 'lecture']
# [datetime.time(16, 20) 'library' 'lication notice board']
# [datetime.datetime(2017, 5, 3, 20, 3) 'IKEA' 'light']
# [datetime.time(23, 36) 'street' 'light']
# [datetime.time(23, 56) 'park' 'light']
# [datetime.time(11, 47) 'home' 'light']
# [datetime.time(15, 5) 'toilet' 'loofah']
# ['pm 18:00' 'home' 'lotion']
# [datetime.datetime(2017, 5, 3, 12, 0) 'Domitory Room' 'lunch']
# ['pm 12:21' 'tomato dosirak' 'lunch box']
# [datetime.time(11, 0) 'Gapyeong' 'lying']
# [datetime.datetime(2017, 5, 2, 14, 28) 'company' 'measuring instrument']
# ['pm 13:00' 'cafe' 'memo pad']
# [datetime.datetime(2017, 5, 5, 14, 29) 'Lotte premium outlet' 'merchandise']
# ['am 11:00' 'class room' 'micro phone']
# [datetime.time(17, 20) 'karaoke room' 'microphone']
# [datetime.time(17, 44) 'university' 'mirror']
# [datetime.time(15, 0) 'school' 'mirror']
# [datetime.datetime(2017, 5, 2, 22, 26) 'home' 'monitor']
# [datetime.time(15, 0) 'lecture room' 'monitor']
# [datetime.time(18, 30) 'church' 'monitor']
# ['pm 16:00' 'home' 'monitor']
# [datetime.time(16, 20) 'pc room' 'monitor']
# [datetime.time(22, 40) 'Si-heung' 'monitor']
# [datetime.time(18, 0) 'home' 'monitor']
# [datetime.time(21, 16) 'home' 'mouse']
# ['am 10:00' 'home' 'mouse']
# ['pm 15:20' 'pc room' 'mouse']
# [datetime.time(11, 20) 'inu' 'movie']
# [datetime.time(23, 0) 'CGV' 'movie']
# ['pm 13:00' 'home' 'multi power point']
# [datetime.time(16, 0) 'car' 'navigation apparatus']
# [datetime.time(13, 41) 'house' 'newspaper']
# [datetime.time(22, 23) 'home' 'night walking']
# [datetime.time(23, 22) 'Dongchun' 'night walking']
# [datetime.time(14, 53) 'classroom' 'note ']
# ['4:52pm' 'Bucheon' 'octopus']
# [datetime.time(15, 0) 'university' 'oscilloscope']
# ['pm 15:05' 'pc room' 'overwatch game']
# [datetime.time(23, 20) 'pc room' 'overwatch game']
# ['am 11:00' 'cafe' 'pansement']
# [datetime.time(16, 7) 'work place' 'paper cup']
# [datetime.datetime(2017, 5, 4, 17, 41) 'Main gate '
#  'park management office']
# ['pm 18:00' 'home' 'parsely bottle']
# [datetime.time(12, 51) 'work place' 'part-time job']
# ['7:19pm' 'supermarket' 'part-time job']
# [datetime.time(9, 55) 'Dongchun' 'part-time job']
# [datetime.time(11, 7) 'Baeksuk-dong' 'part-time job']
# ['pm 20:18' 'home' 'pdf file and note']
# [datetime.time(12, 50) 'cafe' 'pencil case']
# [datetime.time(11, 46) '518 lecture room' 'pencil, paper']
# [datetime.time(15, 4) '213 lecture room' 'pencil, paper']
# [datetime.time(12, 0) 'home' 'piggy bank']
# [datetime.time(16, 0) 'home' 'pillow']
# ['pm 19:28' 'restaurent' 'pizzs']
# [datetime.datetime(2017, 5, 5, 10, 35) 'kitchen' 'plate']
# [datetime.time(17, 46) 'restaurent' 'pork']
# ['7:00pm' 'Restaurant' 'pork']
# ['7:29pm' 'Bupyeong' 'pork']
# ['pm 15:30' 'cafe' 'portable vinyl pack']
# [datetime.datetime(2017, 4, 30, 20, 45) 'Convenience Store' 'pos terminal']
# [datetime.datetime(2017, 5, 3, 23, 22) 'Convenience Store' 'pos terminal']
# [datetime.datetime(2017, 4, 29, 20, 4) 'Convenience Store' 'pos terminal']
# [datetime.datetime(2017, 4, 29, 23, 12) 'Convenience Store' 'pos terminal']
# [datetime.datetime(2017, 5, 3, 19, 48) 'Convenience Store' 'pos terminal']
# [datetime.time(21, 3) 'Guwol-dong' 'postbox']
# ['1:13pm' 'home' 'pot']
# ['12:38pm' 'home' 'pot']
# [datetime.time(18, 30) 'Eul-wang-ri' 'pot']
# ['pm 18:44' 'restaurent' 'potato chips']
# [datetime.time(19, 0) 'bus' 'pouch']
# [datetime.datetime(2017, 5, 1, 13, 0) 'Classroom' 'ppt']
# [datetime.datetime(2017, 5, 2, 17, 0) 'Home' 'printer']
# [datetime.time(11, 0) 'lecture room' 'professor']
# [datetime.time(14, 0) 'lecture room' 'professor']
# ['pm 23:50' 'home' "puppy's pocket home"]
# ['pm 18:00' 'home' 'push-up bar']
# [datetime.time(19, 34) 'home' 'ramen']
# [datetime.time(8, 40) 'songdo' 'recording']
# [datetime.datetime(2017, 4, 30, 13, 56) 'home' 'refrigerator']
# ['pm 19:00' 'home ' 'refrigerator']
# ['pm 16:00' 'home' 'remote controller']
# ['12:44pm' 'kimbab heaven' 'rice']
# [datetime.time(10, 0) 'bongousse' 'riceburger']
# ['11:50am' 'wolmi do' 'rides']
# [datetime.time(10, 20) 'INU' 'road']
# [datetime.time(12, 1) 'songdo' 'school']
# [datetime.time(22, 2) 'Bupyeong' 'screen door']
# [datetime.time(19, 25) 'restaurent' 'seafood']
# [datetime.time(9, 25) 'home' 'second battery']
# [datetime.time(12, 35) 'songdo' 'separate garbage collection']
# ['am 10:00' 'home' 'shampoo']
# ['am 10:00' 'home' 'shampoo']
# ['pm 14:00' 'cafe' 'sharp pencil']
# ['am 11:00' 'fashion market' 'shoes']
# [datetime.time(18, 0) 'bus' 'shoes']
# [datetime.time(19, 55) 'Bucheon ' 'shoes']
# ['pm 15:00' 'road' 'shoes']
# [datetime.time(17, 0) 'Bucheon ' 'shopping']
# ['4:55pm' 'Dongchun' 'shopping']
# [datetime.time(17, 7) 'Dongchun' 'shopping']
# [datetime.time(19, 0) 'sang-dong' 'shopping bag']
# [datetime.time(22, 15) 'Emart' 'shopping cart']
# [datetime.time(9, 38) 'street' 'sign']
# [datetime.time(17, 0) 'Eul-wang-ri' 'singing machine']
# [datetime.time(13, 0) 'inu club room' 'singing practice']
# [datetime.time(16, 0) 'inu club room' 'singing practice']
# [datetime.time(23, 22) 'home' 'sleeping with dog']
# [datetime.time(11, 0) 'Home' 'smart phone']
# [datetime.time(20, 0) 'Guwol-dong' 'smart phone']
# [datetime.time(17, 0) 'home' 'smart phone']
# [datetime.time(21, 15) 'store' 'smartphone']
# [datetime.time(11, 46) 'resturant' 'smartphone']
# [datetime.time(11, 46) 'restaurant' 'smartphone']
# [datetime.time(11, 49) 'home' 'smartphone']
# [datetime.time(13, 35) 'cafe' 'smartphone']
# [datetime.time(11, 55) 'university' 'smartphone']
# ['7:31pm' "grandmother's house" 'smartphone']
# [datetime.time(11, 46) 'home' 'smartphone']
# [datetime.time(18, 58) 'home' 'smartphone']
# [datetime.time(18, 47) 'restaurant' 'smartphone']
# [datetime.time(13, 35) 'bus' 'smartphone']
# [datetime.time(11, 24) 'bus' 'smartphone']
# [datetime.time(11, 23) 'bus' 'smartphone']
# [datetime.time(13, 37) 'street' 'smartphone']
# [datetime.time(16, 50) 'university' 'smartphone']
# [datetime.time(11, 48) 'market' 'smartphone']
# [datetime.time(18, 56) 'subway' 'smartphone']
# [datetime.time(16, 6) 'coast' 'smartphone']
# [datetime.datetime(2017, 5, 1, 10, 33) 'home' 'smartphone']
# [datetime.time(18, 56) 'home' 'smartphone']
# [datetime.time(22, 38) 'home' 'smartphone']
# [datetime.time(16, 8) 'hair salon' 'smartphone']
# [datetime.time(12, 36) 'school cafeteria' 'smartphone']
# [datetime.time(16, 8) 'home' 'smartphone']
# [datetime.time(21, 18) 'coast' 'smartphone']
# [datetime.time(21, 18) 'restaurant' 'smartphone']
# [datetime.time(21, 18) 'ice cream shop' 'smartphone']
# [datetime.time(12, 34) 'park' 'smartphone']
# [datetime.time(12, 33) 'restaurant' 'smartphone']
# [datetime.time(12, 33) 'subway' 'smartphone']
# [datetime.time(21, 7) 'university' 'smartphone']
# [datetime.time(21, 7) 'subway' 'smartphone']
# [datetime.time(21, 6) 'restaurant' 'smartphone']
# [datetime.time(22, 37) 'subway' 'smartphone']
# [datetime.time(22, 38) 'home' 'smartphone']
# [datetime.time(20, 59) 'restaurant' 'smartphone']
# [datetime.time(13, 48) 'university' 'smartphone']
# [datetime.time(21, 13) 'restaurant' 'smartphone']
# [datetime.time(11, 55) 'university' 'smartphone']
# [datetime.time(13, 46) 'university' 'smartphone']
# [datetime.time(13, 46) 'university' 'smartphone']
# ['pm 15:30' 'cafe' 'smartphone battery']
# [datetime.time(11, 43) 'convenience store' 'snack']
# [datetime.time(12, 0) 'street' 'snack']
# [datetime.time(18, 0) 'Campus' 'soccer']
# ['pm 21:41' 'Guwol-dong' 'soju']
# [datetime.time(22, 0) 'bar' 'soju']
# ['pm 22:17' 'bar' 'soju and beer']
# ['pm 20:26' 'bar' 'soju and beer']
# [datetime.time(19, 0) 'home' 'soju and friend']
# [datetime.time(19, 0) 'bus stop' 'soldier friend']
# [datetime.time(10, 0) 'restaurent' 'spoon']
# [datetime.time(20, 32) 'cafe' 'stair']
# ['pm 23:12' 'home' 'stand light']
# [datetime.time(18, 18) 'market' 'starwberry']
# ['pm 13:00' 'subway station' 'strap']
# ['am 11:36' 'hong-dae' 'street']
# ['3:49pm' 'inu' 'street']
# ['7:30pm' 'Jeon-ju' 'street food ']
# [datetime.time(11, 7) 'Guwol-dong' 'study ']
# [datetime.time(12, 1) 'songdo' 'studyroom']
# [datetime.time(21, 15) 'woninjae' 'subway']
# ['10:38pm' 'Daerim station' 'subway']
# [datetime.time(18, 17) 'technopark station' 'subway']
# ['12:56pm' 'Incheon University station' 'subway']
# [datetime.datetime(2017, 5, 1, 20, 0) 'Subway line 7' 'subway']
# [datetime.time(14, 0) 'sang-bong station' 'subway']
# ['10:10pm' 'Inha University' 'subway']
# [datetime.datetime(2017, 5, 4, 9, 26) 'Subway Station' 'subway']
# ['9:42pm' 'Bupyeong' 'subway']
# [datetime.time(13, 55) 'sang-bong station' 'subway chair']
# [datetime.time(18, 30) 'sang-bong station' 'subway chair']
# [datetime.time(15, 5) 'subway station' 'subway information system']
# ['3:38pm' 'subway station' 'subway system']
# [datetime.time(13, 55) 'subway' 'subway system']
# [datetime.time(20, 23) 'subway' 'subway system']
# [datetime.time(11, 20) 'church' 'sundayschool teacher']
# ['pm 19:00' 'home' 'swamp cooler']
# ['pm 12:01' 'inu' 'table']
# ['pm 21:08' 'cafe' 'table']
# [datetime.time(18, 30) 'church' 'table']
# [datetime.time(17, 0) 'baseball stadium' 'ticket']
# [datetime.time(17, 16) 'student restaurant' 'ticket vending machine']
# ['pm 19:00' 'home' 'tissue holder']
# [datetime.datetime(2017, 5, 1, 13, 0) 'lotteria' 'tissue machine']
# ['pm 18:11' 'home' 'toast']
# ['pm 12:41' 'restaurent' 'toast']
# ['pm 15:00' 'cafe' 'trach can']
# [datetime.time(10, 23) 'station' 'train']
# ['2:21pm' 'inu' 'tree']
# [datetime.time(16, 9) 'park' 'tree']
# [datetime.time(16, 48) 'university' 'tree']
# [datetime.time(15, 50) 'street' 'tree']
# [datetime.time(19, 34) 'university' 'tree']
# [datetime.time(16, 24) 'park' 'tree']
# [datetime.time(13, 6) 'park' 'tree']
# [datetime.time(10, 7) 'Seoul' 'tree']
# ['1:10pm' 'sang-dong' 'tree']
# ['1:58pm' 'park' 'tree']
# ['pm 12:21' 'kimbab heaven' 'tteokbokki']
# [datetime.time(11, 56) 'school cafeteria' 'tv']
# [datetime.datetime(2017, 5, 3, 17, 0) 'Domitory Room' 'tv']
# [datetime.time(21, 16) 'home' 'tv']
# ['pm 16:00' 'home' 'umbrella']
# [datetime.time(19, 0) 'toilet' 'urinal']
# [datetime.datetime(2017, 5, 5, 10, 39) 'House' 'vacuum machine']
# ['am 10:00' 'home' 'vacuuum']
# ['am 11:00' 'subway station' 'vending machine']
# [datetime.time(19, 22) 'Guwol-dong' 'vibrating bell']
# ['pm 22:14' 'restaurent' 'vibrating bell']
# [datetime.time(18, 30) 'Gapyeong' 'volleyball']
# ['pm 15:21' 'hospital' 'waiting display']
# ['pm 15:04' 'dental hospital' 'waiting seats']
# ['6:42pm' 'park' 'walking']
# [datetime.time(20, 40) 'inu' 'walking']
# ['am 00:21' 'street' 'walking']
# [datetime.datetime(2017, 4, 30, 15, 0) 'Central park' 'walking']
# [datetime.time(23, 0) 'home' 'walking']
# ['11:58pm' 'Sondo' 'walking']
# [datetime.datetime(2017, 4, 29, 11, 0) 'Central park' 'walking']
# [datetime.time(14, 35) 'park' 'walking with dog']
# [datetime.time(21, 0) 'cafe' 'wallet']
# [datetime.time(15, 0) 'university' 'wallet']
# [datetime.time(20, 0) 'songdo megabox' 'watching movie']
# [datetime.time(22, 48) 'bus ' 'window']
# ['5:49pm' 'Bucheon ' 'window']
# [datetime.time(19, 55) 'home' 'window']
# [datetime.time(10, 34) 'seoul expo' 'wine']
# [datetime.datetime(2017, 4, 30, 14, 31) 'Restaurant' 'wireless bell']
# [datetime.time(22, 0) '영화관' '영화감상']

# %%
sentences = word2vec.Text8Corpus('sentences.txt')

# %%
model = word2vec.Word2Vec(sentences, size=100, window=5, min_count=5, workers=4)
# Out:
# 2017-11-10 14:32:39,933 : INFO : collecting all words and their counts
# 2017-11-10 14:32:39,941 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-11-10 14:32:39,943 : INFO : collected 538 word types from a corpus of 1350 raw words and 1 sentences
# 2017-11-10 14:32:39,944 : INFO : Loading a fresh vocabulary
# 2017-11-10 14:32:39,946 : INFO : min_count=5 retains 49 unique words (9% of original 538, drops 489)
# 2017-11-10 14:32:39,947 : INFO : min_count=5 leaves 694 word corpus (51% of original 1350, drops 656)
# 2017-11-10 14:32:39,949 : INFO : deleting the raw counts dictionary of 538 items
# 2017-11-10 14:32:39,951 : INFO : sample=0.001 downsamples 49 most-common words
# 2017-11-10 14:32:39,952 : INFO : downsampling leaves estimated 173 word corpus (25.1% of prior 694)
# 2017-11-10 14:32:39,953 : INFO : estimated required memory for 49 words and 100 dimensions: 63700 bytes
# 2017-11-10 14:32:39,954 : INFO : resetting layer weights
# 2017-11-10 14:32:39,957 : INFO : training model with 4 workers on 49 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2017-11-10 14:32:39,964 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-11-10 14:32:39,965 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-11-10 14:32:39,966 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-11-10 14:32:39,967 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-11-10 14:32:39,968 : INFO : training on 6750 raw words (810 effective words) took 0.0s, 102018 effective words/s
# 2017-11-10 14:32:39,969 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
print(model)
# Out:
# Word2Vec(vocab=49, size=100, alpha=0.025)

# %%
words = list(model.wv.vocab)
print(words)
# Out:
# ['posterminal', 'TV', 'car', 'classroom', 'library', 'DomitoryRoom', 'walking', 'Dormitory', 'computer', 'Restaurant', 'Guwol-dong', 'desktop', 'cafe', 'Billiardroom', 'House', 'park', 'Dongchun', 'bar', 'pcroom', 'laptop', 'home', 'food', 'monitor', 'Busan', 'Bupyeong', 'Home', 'tree', 'smartphone', 'ConvenienceStore', 'flowerpot', 'inu', 'subwaystation', 'Bus', 'busstop', 'restaurant', 'Book', 'Bucheon', 'Hamburger', 'Dinner', 'songdo', 'street', 'Street', 'bus', 'restaurent', 'book', 'house', 'cloth', 'subway', 'university']

# %%
print(model[['car']])
# Out:
# [[-0.0020674   0.00915548 -0.00671983  0.00096454 -0.00243635  0.0053119
#   -0.00519592 -0.00890965 -0.00104819 -0.0062596  -0.00691033  0.00259498
#    0.00233858  0.00539081 -0.00235634  0.0012159  -0.00243391  0.00366964
#   -0.00046581 -0.00329159  0.00949203  0.00166369  0.00065795  0.00123992
#   -0.00430724  0.00430569  0.00284354 -0.00055736 -0.005178   -0.00852255
#    0.00232498 -0.01015786 -0.00359028  0.00027806 -0.00537587 -0.00040143
#    0.00418258  0.00186363  0.00668143 -0.00781117  0.00483913 -0.00300776
#   -0.00116508  0.00580826 -0.00013086 -0.00495558 -0.00492946 -0.00560568
#    0.00324123 -0.00185826 -0.0045104   0.00309404  0.004149   -0.00202472
#   -0.000329    0.00495229 -0.0152264  -0.00374458 -0.00481751  0.00117512
#   -0.00895356 -0.00210681  0.00375971  0.00336154 -0.00340515  0.00102935
#    0.00593501  0.00477605  0.00295691  0.0019565   0.00431572 -0.00250111
#   -0.00333933 -0.00523481 -0.00110747  0.00577708  0.0017995  -0.00095386
#    0.00924192  0.00488789 -0.00383835  0.00131969 -0.0010853  -0.00068079
#   -0.00289967  0.00411689 -0.00586891  0.00221443  0.00189816 -0.00029198
#   -0.00637762  0.00331787 -0.0020685   0.00607095 -0.00848293  0.00219167
#    0.00591712  0.0013307  -0.00864477  0.0074203 ]]

# %%
model.wv.save_word2vec_format('model.bin')
# Out:
# 2017-11-10 14:35:01,051 : INFO : storing 49x100 projection weights into model.bin

# %%
model.wv.save_word2vec_format('model.txt', binary = False)
# Out:
# 2017-11-10 14:35:17,886 : INFO : storing 49x100 projection weights into model.txt

# %%
import gensim.models.keyedvectors as word2vec
new_model = word2vec.KeyedVectors.load_word2vec_format('model.bin')
print(new_model)
# Out:
# 2017-11-10 14:35:18,453 : INFO : loading projection weights from model.bin
# 2017-11-10 14:35:18,466 : INFO : loaded (49, 100) matrix from model.bin
# <gensim.models.keyedvectors.KeyedVectors object at 0x7f202f7f31d0>

# %%
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.title('User response analysis using PCA')
pyplot.scatter(result[:, 0], result[:,1 ])
words = list(model.wv.vocab)
for i, word in enumerate(words):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.grid(True)
pyplot.show()
